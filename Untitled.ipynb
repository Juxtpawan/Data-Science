# %% [markdown]
# <a href="https://colab.research.google.com/github/Juxtpawan/Data-Science/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%time
import numpy as np
a = np.arange(1, 100000)
b =np.arange(2, 100001)
c = a+b
print(c)
# Out:
# [     3      5      7 ... 199995 199997 199999]
# CPU times: user 1.88 ms, sys: 1.98 ms, total: 3.86 ms
# Wall time: 2.88 ms
